# %% [markdown]
# <a href="https://colab.research.google.com/github/divyasaiachanta/Generative-AI/blob/main/product_review_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers pandas
from transformers import pipeline
import pandas as pd

# %%
sentiment=pipeline("sentiment-analysis")
reviews="""The laptop starts quickly and works smoothly for daily tasks.
The screen quality is clear and good for watching videos.
Battery backup is average and needs charging often.
The fan makes noise when many apps are running.
Overall, it is a good laptop for Students but not for gaming.
"""
sentences=reviews.split(".")
pros = []
cons = []
for s in sentences:
    s=s.strip()
    if s=="":
      continue
    result=sentiment(s)[0]
    if result["label"]=="POSITIVE":
      pros.append(s)
    elif result["label"]=="NEGATIVE":
      cons.append(s)

pros = pros[:2]
cons = cons[:2]
df=pd.DataFrame({
    "pros":pros,
    "cons":cons
})
df
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
#                                                 pros  \
# 0  The laptop starts quickly and works smoothly f...
# 1  The screen quality is clear and good for watch...
#
#                                                 cons
# 0  Battery backup is average and needs charging o...
# 1     The fan makes noise when many apps are running
